// %%
Question 1: What data type is each of the following? 
    
5 - int32
5.0 - double
5 > 1 - boolean
'5' - schar
5 * 2 - int32
'5' * 2 - int32 //as it gets the ascii value of the character, verified the values
'5' + '2' - int32 //same as above
5 / 2 - int32 //jupyter by default treats it as integer, double or float can be specified
5 % 2 - int32 //same as above
{5, 2, 1} - list
5 == 3 - boolean
Pi (the number) - double for 3.14

// %%
Question 2: Write (and evaluate) C# expressions that answer these questions:

a. How many letters are there in 'Supercalifragilisticexpialidocious'?
myString = "Supercalifragilisticexpialidocious";
int string1 = myString.Length; //length
int string2 = myString.Count(char.IsLetter); //for only the count of letters
Console.WriteLine($"Length output - {string1}");
Console.WriteLine($"Count output - {string2}");

b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring? 
myString = "Supercalifragilisticexpialidocious";
Console.WriteLine(myString.Contains("ice"));

c. Which of the following words is the longest:
Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
Bababadalgharaghtakamminarronnkonn?
string string1 = "Supercalifragilisticexpialidocious";
string string2 = "Honorificabilitudinitatibus";
string string3 = "Bababadalgharaghtakamminarronnkonn";

int len1 = string1.Length;
int len2 = string2.Length;
int len3 = string3.Length;

if (len1>=len2 && len1>=len3)
        if(len1==len2)
            Console.WriteLine($"{string1} and {string2} are the longest");
        else if (len1==len3)
            Console.WriteLine($"{string1} and {string3} are the longest");
        else
            Console.WriteLine($"{string1} is the longest");      
    else if (len2>=len1 && len2>=len3)
        if(len2==len3)
            Console.WriteLine($"{string2} and {string3} are the longest");
        else
            Console.WriteLine($"{string2} is the longest");  
    else 
        Console.WriteLine($"{string3} is the longest");



d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?
Dictionary<int, string> compDict = new Dictionary<int, string>(); 
compDict.Add(1, "Berlioz");
compDict.Add(2, "Borodin");
compDict.Add(3, "Brian");
compDict.Add(4, "Bartok");
compDict.Add(5, "Bellini");
compDict.Add(6, "Buxtehude");
compDict.Add(7, "Bernstein");

Console.WriteLine("First composer: " + compDict.First().Value);
Console.WriteLine("Last composer: " + compDict.Last().Value);
// Out:
// (1,10): error CS1002: ; expected
// (1,11): error CS1002: ; expected
// (1,11): error CS7017: Member definition, statement, or end-of-file expected
// (1,24): error CS1003: Syntax error, ',' expected
// (1,34): error CS1002: ; expected
// (1,35): error CS1040: Preprocessor directives must appear as the first non-whitespace character on a line
// (3,8): error CS1003: Syntax error, '(' expected
// (3,21): error CS1003: Syntax error, ',' expected
// (3,31): error CS1003: Syntax error, ',' expected
// (3,34): error CS1031: Type expected
// (3,34): error CS1001: Identifier expected
// (3,34): error CS1012: Too many characters in character literal
// (3,71): error CS1003: Syntax error, ',' expected
// (4,10): error CS1001: Identifier expected
// (4,48): error CS1026: ) expected
// (10,9): error CS1002: ; expected
// (10,9): error CS1012: Too many characters in character literal
// (10,46): error CS1002: ; expected
// (10,54): error CS1002: ; expected
// ...

// %%
Question 3 C#
Implement function triangleArea(a,b,c) that takes as input the lengths of the 3 sides of a triangle and returns the area of the triangle. By Heron's formula, the area
of a triangle with side lengths a, b, and c is 
s(s - a)(s -b)(s -c), where
s = (a+b+c)/2.
>>> triangleArea(2,2,2)
1.7320508075688772

double s, area;
double a = 2;
double b = 2;
double c = 2;
/*            Console.WriteLine("Enter side #1");
            a = double.Parse(Console.ReadLine());
            Console.WriteLine("Enter side #2");
            b = double.Parse(Console.ReadLine());
            Console.WriteLine("Enter side #3");
            c = double.Parse(Console.ReadLine());
*/
s = (a + b + c) / 2;
area = Math.Sqrt(s * ( s - a) * (s - b) * (s - c)); 
Console.WriteLine("Area = {0}", area);
// Out:
// (1,10): error CS1002: ; expected
// (1,12): error CS1002: ; expected
// (1,13): error CS1040: Preprocessor directives must appear as the first non-whitespace character on a line
// (2,11): error CS1002: ; expected
// (2,34): error CS1001: Identifier expected
// (2,36): error CS1001: Identifier expected
// (2,38): error CS1001: Identifier expected
// (2,40): error CS1002: ; expected
// (2,51): error CS1002: ; expected
// (2,51): error CS1525: Invalid expression term 'as'
// (2,60): error CS1002: ; expected
// (2,72): error CS1002: ; expected
// (2,79): error CS1002: ; expected
// (2,81): error CS1002: ; expected
// (2,90): error CS1002: ; expected
// (2,101): error CS1002: ; expected
// (2,113): error CS1002: ; expected
// (2,122): error CS1002: ; expected
// (2,129): error CS1002: ; expected
// (2,147): error CS1002: ; expected
// (2,147): error CS1010: Newline in constant
// (2,147): error CS1012: Too many characters in character literal
// (2,167): error CS1002: ; expected
// ...

// %%
Question 4: Write a program in C# Sharp to separate odd and even integers in separate arrays.
Go to the editor
Test Data :
Input the number of elements to be stored in the array :5
Input 5 elements in the array :
element - 0 : 25
element - 1 : 47
element - 2 : 42
element - 3 : 56
element - 4 : 32
Expected Output:
The Even elements are:
42 56 32
The Odd elements are :
25 47

/*
            Console.WriteLine("Enter the Maximum Range of the Array");
            N = Convert.ToInt32(Console.ReadLine());
            Console.WriteLine("Enter the Input Values to the Array");
            int[] a = new int[N];
            int[] even = new int[N];
            int[] odd = new int[N];
            for (i = 0; i < N; i++)
            {
                a[i] = Convert.ToInt32(Console.ReadLine());
            }
            Console.WriteLine("The Input Elements are:");
            for (i = 0; i < N; i++)
            {
                Console.WriteLine(a[i]);
            }
*/

int i,j;
int N=5;
int[] even = new int[N];
int[] odd = new int[N];
int[] arr = new int[N];        
        arr[0] = 25;
        arr[1] = 47;
        arr[2] = 42;
        arr[3] = 56;
        arr[4] = 32;

Console.WriteLine("Finding of Even and odd Values in the given array and store them as separate arrays");

for (i = 0; i < N; i++)
    {
        if (arr[i] % 2 == 0)
            {
                even[i] = arr[i];
            }
        else
            {
                odd[i] = arr[i];
            }
    }
Console.WriteLine("The even values are:");
for (i = 0; i < even.Length; i++)
    {
        if (even[i] == 0)
            {
                Console.Write("");
            }
        else
               Console.WriteLine(even[i]);
    }
Console.WriteLine("The odd values are");
for (i = 0; i < odd.Length; i++)
    {
        if (odd[i] == 0)
            {
                Console.Write("");
            }
         else
                Console.WriteLine(odd[i]);
     }
// Out:
//   File "C:\Users\Anant\AppData\Local\Temp/ipykernel_2020/2917131456.py", line 1
//     using System;
//           ^
// SyntaxError: invalid syntax

// %%
Question 5 C#
a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False depending on whether the point (x,y) lies in the 
rectangle with lower left corner (x1,y1) and upper right corner (x2,y2).
>>> inside(1,1,0,0,2,3)
True
>>> inside(-1,-1,0,0,2,3)
False
b. Use function inside() from part a. to write an expression that tests whether the point (1,1) lies in both of the following rectangles: one with lower left
corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower left corner (0.5, 0.2) and upper right corner (1.1, 2). 

//running on visual studio
using System;

class GFG
{
    static bool inside(int x, int y, int x1, int y1, int x2, int y2)
    {
        if (x > x1 && x < x2 && y > y1 && y < y2)
            return true;
        return false;
    }

    public static void Main()
    {
        int x1 = 0, y1 = 0, x2 = 2, y2 = 3; //rectangle coordinates
        int x = -1, y = -1; //given point
        
        if (inside(x, y, x1, y1, x2, y2))
            Console.Write("True");
        else
            Console.Write("False");
    }
}
